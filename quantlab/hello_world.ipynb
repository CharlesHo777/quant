# %%
import vectorbt as vbt

price = vbt.YFData.download("AAPL", start="2015-01-01").get("Close")
fast, slow = vbt.MA.run(price, 20), vbt.MA.run(price, 100)
entries = fast.ma_crossed_above(slow)     # buy when 20-day avg crosses above 100-day
exits   = fast.ma_crossed_below(slow)     # sell on the reverse
pf = vbt.Portfolio.from_signals(price, entries, exits, fees=0.001, freq="1D")
print(pf.stats())
pf.plot().show()
# Out:
# Start                         2014-12-31 05:00:00+00:00
# End                           2026-08-11 04:00:00+00:00
# Period                               2919 days 00:00:00
# Start Value                                       100.0
# End Value                                    373.186159
# Total Return [%]                             273.186159
# Benchmark Return [%]                        1148.939246
# Max Gross Exposure [%]                            100.0
# Total Fees Paid                                8.445742
# Max Drawdown [%]                              35.639102
# Max Drawdown Duration                 730 days 00:00:00
# Total Trades                                         20
# Total Closed Trades                                  19
# Total Open Trades                                     1
# Open Trade PnL                                42.647823
# Win Rate [%]                                  52.631579
# Best Trade [%]                                55.986469
# Worst Trade [%]                              -14.733329
# Avg Winning Trade [%]                         22.701989
# Avg Losing Trade [%]                           -8.21986
# Avg Winning Trade Duration     160 days 16:47:59.999999
# Avg Losing Trade Duration              27 days 10:40:00
# Profit Factor                                  2.327166
# Expectancy                                    12.133597
# Sharpe Ratio                                   0.756497
# Calmar Ratio                                   0.502268
# Omega Ratio                                    1.151745
# Sortino Ratio                                  1.092977
# dtype: object
